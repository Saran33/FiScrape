# %%
import scrapy
import pandas as pd
from readability.readability import Document
from datetime import date, datetime

from dateutil import parser

from pytz import timezone
from dateutil import parser

# %% [markdown]
# ### Load a CSV into DB

# %%
# start_date = datetime.utcnow()
start_date = '2021-01-01'
start_date = datetime.strptime(start_date,'%Y-%m-%d')
# start_date = start_date.replace(hour=0, minute=0, second=0, microsecond=0)

# %%
start_date = timezone("UTC").localize(start_date)
print (start_date.tzinfo)
# Out:
# UTC

# %%
start_date
# Out:
# datetime.datetime(2021, 1, 1, 0, 0, tzinfo=<UTC>)

# %%
# import sqlalchemy as db
from sqlalchemy import create_engine
engine = create_engine('sqlite:///openblender.db')
connection = engine.connect()

f_name = "output.csv"
with open(f_name, 'r') as file:
    df = pd.read_csv(f_name, parse_dates=['published_date'])
df.to_sql('btc_openblender', con=engine)

# %%
f_name = "output.csv"
df = pd.read_csv(f_name, parse_dates=['published_date'])
df
# Out:
#                                          article_link  \
# 0   https://www.ft.com/content/97ae26a3-5ab6-4eaa-...
# 1   https://www.ft.com/content/402a5425-bfd9-43a6-...
# 2   https://www.ft.com/content/57ef63ba-a1ee-4001-...
# 3   https://www.ft.com/content/8e3784f8-5605-40aa-...
# 4   https://www.ft.com/content/8e955e9a-6e03-41b9-...
# 5   https://www.ft.com/content/6fc8ed49-2fa9-4388-...
# 6   https://www.ft.com/content/65beb1a8-dc0b-4c10-...
# 7   https://www.ft.com/content/b2fada0d-473b-4e45-...
# 8   https://www.ft.com/content/3a820200-0128-42b3-...
# 9   https://www.ft.com/content/fc50c983-3e81-4cc6-...
# 10  https://www.ft.com/content/f928d37b-6f9b-465f-...
# 11  https://www.ft.com/content/beeb2f8c-99ec-494b-...
# 12  https://www.ft.com/content/c7bf6cf3-4167-49cb-...
# 13  https://www.ft.com/content/8b1f5ac1-e579-4ff5-...
# 14  https://www.ft.com/content/7a4142dd-a472-4675-...
# 15  https://www.ft.com/content/bad3ed79-6e06-4a35-...
# 16  https://www.ft.com/content/e500c809-a05d-4852-...
# 17  https://www.ft.com/content/dff39335-95a2-4aee-...
# 18  https://www.ft.com/content/dccac69e-9ebe-468a-...
# 19  https://www.ft.com/content/842415ec-06cb-437b-...
# 20  https://www.ft.com/content/0804d517-dc89-45fa-...
# 21  https://www.ft.com/content/74ba1d2c-6bf0-4429-...
# 22  https://www.ft.com/content/8dc38c24-8da1-40a0-...
# 23  https://www.ft.com/content/5bf9fd34-e7cb-4176-...
# 24  https://www.ft.com/content/9e787670-6aa7-4479-...
# 25  https://www.ft.com/content/356dfe4a-0956-4946-...
# 26  https://www.ft.com/content/afd04de8-21f0-4262-...
# 27  https://www.ft.com/content/949ee788-6630-4aac-...
# 28  https://www.ft.com/content/b4925984-821c-45ef-...
# 29  https://www.ft.com/content/8f2deb75-939f-463b-...
# 30  https://www.ft.com/content/fd65b82e-9e43-4e22-...
# 31  https://www.ft.com/content/8b61c731-073f-46f1-...
# 32  https://www.ft.com/content/124d2fa4-3d89-46cb-...
# 14  ...from theory to practice In Latin America, E...
# 15  ...of Big Tech to tackle the threat posed by t...
# 16  ...by retail investors, such as Robinhood and ...
# 17  ...crypto platforms on the London Underground....
# 18  ...Center at Korea University.\n\t\t\t\t\t\t\n...
# 19                          ...As the cryptocurrency
# 20  ...believer Michael Saylor, they are not using...
# 21  ...where prices were rising even as El Salvado...
# 22  ...Major central banks have been slow to respo...
# 23  ...group, said it has borrowed £18.1m using a ...
# 24  ...is perhaps its most enduring mystery. In 20...
# 25  ...77 per cent — thought El Salvador was makin...
# 26  ...York Times, $)\n\t\t\t\t\t\t\n\t\t\t\t\t\t-...
# 27  ...s first crypto conglomerate, a network of f...
# 28                                  ...El Salvador’s
# 29  ...to be solved. The Internet of (Five) Things...
# 30  Trading app’s intended audience may not be reg...
# 31  ...reading FirstFT — GordonFive more stories i...
# 32  ...it said.Beyond the Square Mile\n\t\t\t\t\t\...
# 33  Cryptocurrency exchange’s chief accuses US reg...
# 34           ...El Salvador’s pioneering adoption of
# 35  ...economy of an impoverished Central American...
# 36  ...Salvador will today become the first countr...
# 37  ...boldness. A campaign on social media invite...
# 38  ...Salvador will today become the first countr...
# 39  ...to secure long-term financing. (FT)\n\t\t\t...
# 40  ...appearance at number eight in 2021. Separat...
# 41  ...Like millions of Salvadorans, chauffeur Ric...
# 42  ...are signs that digital coins are building d...
# 43  ...women in China, gain their trust and entice...
# 44  ...In Lagos, Nigeria’s commercial capital, a s...
# 45  ...be largely captured by existing securities ...
# 46  ...the London main-market listed cryptocurrenc...
# 47  ...cryptocurrency fraud registration: a high-v...
# 48  ...of stress.\n\t\t\t\t\t\t\n\t\t\t\t\t\tThere...
# 49  ...funds. But if they are sure of the authenti...
#
#                                 tags
# 0                             Letter
# 1                            FirstFT
# 2                      FT Alphaville
# 3                         Transcript
# 4                   Cryptocurrencies
# 5                            FirstFT
# 6                      City Bulletin
# 7                      Due Diligence
# 8                   Cryptocurrencies
# 9                            Bitcoin
# 10                           #techFT
# 11                      The Big Read
# 12                       Hedge funds
# 13                  Cryptocurrencies
# 14                        #fintechFT
# 15                     FT Alphaville
# 16                    Brooke Masters
# 17               Latest news on ETFs
# 18                  Cryptocurrencies
# 19                       El Salvador
# 20                      Katie Martin
# 21                               Lex
# 22                  Cryptocurrencies
# 23                     City Bulletin
# 24                       FT Magazine
# 25                           FirstFT
# 26                     FT Alphaville
# 27                       FT Magazine
# 28                  Cryptocurrencies
# 29                           #techFT
# 30                          Coinbase
# 31                           FirstFT
# 32                     City Bulletin
# 33                          Coinbase
# 34                           Bitcoin
# 35                           Bitcoin
# 36                           FirstFT
# 37               The editorial board
# 38                        Transcript
# 39                     Due Diligence
# 40                           #techFT
# 41                           Bitcoin
# 42                           FirstFT
# 43                       Nikkei Asia
# 44                      The Big Read
# 45                  Cryptocurrencies
# 46                     City Bulletin
# 47  Watches and Jewellery: September
# 48                Digital currencies
# 49         FT Wealth: September 2021

# %%
df['author_bio'].value_counts()
# Out:
# Bangkok correspondent                3
# West Africa correspondent            3
# M&A correspondent                    1
# Deputy editor, FT Wealth magazine    1
# Chief Business Commentator           1
# ETF correspondent                    1
# Name: author_bio, dtype: int64

# %%
dt = "2021-09-17T04:01:00+0000"

dtt = datetime.strptime(dt,"%Y-%m-%dT%H:%M:%S%z")
print(dtt)
# Out:
# 2021-09-17 04:01:00+00:00

# %%
dt = "March 14, 1879 T04:01:00+0000 "

dtt = parser.parse(dt)
print (dtt)
# Out:
# 1879-03-14 04:01:00+00:00

# %%
dtt.tzinfo
# Out:
# tzutc()

# %%
dt.strip()
# Out:
# 'March 14, 1879 T04:01:00+0000'

# %%
def extract_headline(text):
    return "".join(text.extract())

text = ['French fund manager to launch first EU-regulated ', 'bitcoin', ' tracker']

print (extract_headline(str(text)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_g/18qnvwy1001_g1m79rrlhjn00000gn/T/ipykernel_98591/583471363.py in <module>
#       4 text = ['French fund manager to launch first EU-regulated ', 'bitcoin', ' tracker']
#       5
# ----> 6 print (extract_headline(str(text)))
#
# /var/folders/_g/18qnvwy1001_g1m79rrlhjn00000gn/T/ipykernel_98591/583471363.py in extract_headline(text)
#       1 def extract_headline(text):
# ----> 2     return "".join(text.extract())
#       3
#       4 text = ['French fund manager to launch first EU-regulated ', 'bitcoin', ' tracker']
#       5
#
# AttributeError: 'str' object has no attribute 'extract'

# %%
news_sites = 'csv_files/news_sites/btc_news_sites.csv'

# %%
sites = pd.read_csv(news_sites)
sites
# Out:
#                     Source                                                URL
# 0                       FT      https://www.ft.com/search?q=Bitcoin&sort=date
# 1                      WSJ  https://www.wsj.com/search?query=Bitcoin&mod=s...
# 2                     CNBC  https://www.cnbc.com/search/?query=Bitcoin&qse...
# 3                Bloomberg     https://www.bloomberg.com/search?query=Bitcoin
# 4                  Reuters  https://www.reuters.com/site-search/?query=Bit...
# 5                   Forbes  https://www.forbes.com/search/?sort=recent&q=b...
# 6                ZeroHedge  https://www.zerohedge.com/search-content?qTitl...
# 7       Seeking Alpha News       https://seekingalpha.com/symbol/BTC-USD/news
# 8   Seeking Alpha Analysis   https://seekingalpha.com/symbol/BTC-USD/analysis
# 9         Business Insider  https://markets.businessinsider.com/currencies...
# 10           Yahoo Finance  https://finance.yahoo.com/quote/BTC-USD?p=BTC-...
# 11                   Kitco            https://www.kitco.com/search/?q=bitcoin
# 12          Financial News            https://www.fnlondon.com/search/bitcoin
# 13            Fast Company  https://www.fastcompany.com/search?searchkey=b...
# 14                     BBC             https://www.bbc.co.uk/search?q=Bitcoin
# 15                     CNN  https://edition.cnn.com/search?q=Bitcoin&size=...
# 16                     Fox  https://www.foxnews.com/search-results/search?...
# 17             Independent        https://www.independent.co.uk/topic/bitcoin
# 18               The Times  https://www.thetimes.co.uk/search?filter=all&q...
# 19            The Guardian     https://www.theguardian.com/technology/bitcoin
# 20                    Vice              https://www.vice.com/en/topic/bitcoin
# 21      The Economic Times  https://economictimes.indiatimes.com/news/bitcoin
# 22                    NDTV     https://www.ndtv.com/search?searchtext=Bitcoin
# 23            Moneycontrol  https://www.moneycontrol.com/news/tags/bitcoin...
# 24                    Mint  https://www.livemint.com/Search/Link/Keyword/B...
# 25                Euronews      https://www.euronews.com/search?query=Bitcoin
# 26             India Today            https://www.indiatoday.in/topic/Bitcoin
# 27             News.com.au   https://www.news.com.au/search-results?q=bitcoin
# 28                  Quartz                     https://qz.com/search/bitcoin/
# 29       Business Standard  https://www.business-standard.com/search?q=Bit...
# 30                  News18             https://www.news18.com/topics/bitcoin/
# 31                CoinDesk                  https://www.coindesk.com/markets/
# 32           Cointelegraph             https://cointelegraph.com/tags/bitcoin
# 33             Bitcoin.com                https://news.bitcoin.com/?s=Bitcoin
# 34        Bitcoin Magazine               https://bitcoinmagazine.com/articles
# 35          The Daily Hodl                https://dailyhodl.com/bitcoin-news/
# 36           Bitboy Crypto                https://bitboycrypto.com/?s=Bitcoin

# %%
# Spider 1 
# Articles.py which scrape article links
# imports
from scrapy.http import Request

class ArticlesSpider(scrapy.Spider):
 name = 'Articles'
 allowed_domains = ['ft.com']
 start_urls = ['https://www.ft.com/']

def start_requests(self):
  # Hardcoded URL that contains TURKEY related subjects
  url="https://www.ft.com/search?q=Bitcoin&sort=date"
  link_urls = [url.format(i) for i in range(0,500)]

  # Loops through 500 pages to get the article links
  for link_url in link_urls:
    print(link_url)

      # Request to get the HTML content
      request=Request(link_url, cookies={'store_language':'en'}, 
      callback=self.parse_main_pages)
  yield request
  def parse_main_pages(self,response):
  item=TrtworldItem()

  # Gets HTML content where the article links are stored
    content=response.xpath('//div[@id="items"]//div[@class="article- 
    meta"]')
    
  # Loops through the each and every article link in HTML 'content'
    for article_link in content.xpath('.//a'):
  # Extracts the href info of the link to store in scrapy item
    item['article_url'] =    
    article_link.xpath('.//@href').extract_first()
  item['article_url'] =   
    "https://www.trtworld.com"+item['article_url']
  yield(item)
  def parse(self, response):
    pass

# %%
'''
headline_scraper.py
A simple scrapy spider to collect web page titles
'''
news_sites = 'csv_files/news_sites/btc_news_sites.csv'


class HeadlineSpider(scrapy.Spider):
    name = "headline_spider"
    start_urls = pd.read_csv(news_sites).url.tolist()

    def parse(self, response):
        doc = Document(response.text)
        yield {
            'short_title': doc.short_title(),
            'full_title': doc.title(),
            'url': response.url
        }

# %%
import scrapy

class FT_Spider(scrapy.Spider):
    #name of the spider
    name = 'ft'

    #list of allowed domains
    allowed_domains = ['ft.com']

    #starting url for scraping
    start_urls = ['https://www.ft.com/search/']

    #setting the location of the output csv file
    custom_settings = {
        'FEED_URI' : 'tmp/ft.csv'
    }

    def parse(self, response):
        #Remove XML namespaces
        response.selector.remove_namespaces()
    
        #Extract article information
        titles = response.xpath('//item/title/text()').extract()
        authors = response.xpath('//item/creator/text()').extract()
        dates = response.xpath('//item/pubDate/text()').extract()
        links = response.xpath('//item/link/text()').extract()

        for item in zip(titles,authors,dates,links):
            scraped_info = {
                'title' : item[0],
                'author' : item[1],
                'publish_date' : item[2],
                'link' : item[3]
            }

            yield scraped_info
